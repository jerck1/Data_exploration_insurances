# %% [markdown]
# # <center> Modelamiento LASSO <center>
# $$\text{minimizar  }\frac{1}{2 n_{samples}} ||y - Xw||^2_2 + \alpha * ||w||_1$$

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from IPython.display import display, HTML
# !(pip install chainladder)
import chainladder as cl # librería para realizar triángulos de pérdidas

#cargamos los modelos lineales con LASSO
from sklearn import linear_model
from sklearn.model_selection import train_test_split #separamos train de test
from sklearn.metrics import mean_squared_error #halla# <center> LASSO <center>rmos el mse con los datos de testeo$$\text{minimizar  }\frac{1}{2 n_{samples}} ||y - Xw||^2_2 + \alpha * ||w||_1$$


print("pandas: " + pd.__version__)
print("numpy: " + np.__version__)
print("chainladder: " + cl.__version__)
# print("sklearn.linear_model: " + sklearn.__version__)
# Out:
# pandas: 1.4.2
# numpy: 1.22.0
# chainladder: 0.8.18

# %% [markdown]
# ## Ingreso de los Datos

# %%
data=pd.read_csv('wkcomp_pos.csv') # cargar o abrir un csv
display(data.head())
# Out:
#    GRCODE               GRNAME  AccidentYear  DevelopmentYear  DevelopmentLag  \
# 0      86  Allstate Ins Co Grp          1988             1988               1
# 1      86  Allstate Ins Co Grp          1988             1989               2
# 2      86  Allstate Ins Co Grp          1988             1990               3
# 3      86  Allstate Ins Co Grp          1988             1991               4
# 4      86  Allstate Ins Co Grp          1988             1992               5
#
#    IncurLoss_D  CumPaidLoss_D  BulkLoss_D  EarnedPremDIR_D  EarnedPremCeded_D  \
# 0       367404          70571      127737           400699               5957
# 1       362988         155905       60173           400699               5957
# 2       347288         220744       27763           400699               5957
# 3       330648         251595       15280           400699               5957
# 4       354690         274156       27689           400699               5957
#
#    EarnedPremNet_D  Single  PostedReserve97_D
# 0           394742       0             281872
# 1           394742       0             281872
# 2           394742       0             281872
# 3           394742       0             281872
# 4           394742       0             281872

# %% [markdown]
# Creamos un triángulo con los datos de entrada, para el análisis vamos a tomar únicamente las variables de pérdida

# %%
triangle = cl.Triangle(
    data,
    origin="AccidentYear", # filas
    development="DevelopmentYear", # columnas
    columns=data.columns[5:], # tomamos en cuenta solamente las columnas de ganancias y pérdidas
    index=["GRNAME"], # nombres de las compañías
    cumulative=False, # triángulo de pérdidas acumulado o no
)
triangle #objeto de pandas
# Out:
#                                              Triangle Summary
# Valuation:                                            2006-12
# Grain:                                                   OYDY
# Shape:                                       (132, 8, 19, 19)
# Index:                                               [GRNAME]
# Columns:    [IncurLoss_D, CumPaidLoss_D, BulkLoss_D, Earne...

# %% [markdown]
# ## Cálculo del triángulo total
#
# Inicialmente, trabajaremos con el triángulo total para observar el comportamiento global de las pérdidas acumuladas.

# %%
total_cum=triangle['CumPaidLoss_D'].sum()
print('age-to-age factors:')
ratios=total_cum.link_ratio
display(ratios.heatmap(cmap='Reds'))
# Out:
# age-to-age factors:
# <style type="text/css">
# #T_3978f_row0_col0, #T_3978f_row0_col4, #T_3978f_row2_col2, #T_3978f_row2_col3, #T_3978f_row6_col1, #T_3978f_row6_col7, #T_3978f_row8_col5, #T_3978f_row9_col6, #T_3978f_row9_col8 {
#   background-color: #f6553c;
#   color: #f1f1f1;
# }
# #T_3978f_row0_col1, #T_3978f_row0_col7, #T_3978f_row1_col2, #T_3978f_row1_col6, #T_3978f_row2_col0, #T_3978f_row2_col5, #T_3978f_row3_col4, #T_3978f_row4_col3, #T_3978f_row6_col8 {
#   background-color: #67000d;
#   color: #f1f1f1;
# }
# #T
{
#   background-color: #fb7c5c;
#   color: #f1f1f1;
# }
# #T_3978f_row2_col6, #T_3978f_row5_col0, #T_3978f_row5_col1, #T_3978f_row5_col5, #T_3978f_row6_col3, #T_3978f_row7_col7, #T_3978f_row8_col8, #T_3978f_row9_col2, #T_3978f_row9_col4 {
#   background-color: #fca082;
#   color: #000000;
# }
# #T_3978f_row2_col8, #T_3978f_row3_col7, #T_3978f_row6_col0, #T_3978f_row7_col3, #T_3978f_row7_col4, #T_3978f_row8_col1, #T_3978f_row8_col2, #T_3978f_row8_col6, #T_3978f_row9_col5 {
#   background-color: #fee3d6;
#   color: #000000;
# }
# #T_3978f_row3_col5, #T_3978f_row3_col8, #T_3978f_row4_col4, #T_3978f_row5_col3, #T_3978f_row6_col2, #T_3978f_row7_col1, #T_3978f_row7_col6, #T_3978f_row8_col0, #T_3978f_row9_col7 {
#   background-color: #fff5f0;
#   color: #000000;
# }
# </style>
# <table id="T_3978f">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_3978f_level0_col0" class="col_heading level0 col0" >12-24</th>
#       <th id="T_3978f_level0_col1" class="col_heading level0 col1" >24-36</th>
#       <th id="T_3978f_level0_col2" class="col_heading level0 col2" >36-48</th>
#       <th id="T_3978f_level0_col3" class="col_heading level0 col3" >48-60</th>
#       <th id="T_3978f_level0_col4" class="col_heading level0 col4" >60-72</th>
#       <th id="T_3978f_level0_col5" class="col_heading level0 col5" >72-84</th>
#       <th id="T_3978f_level0_col6" class="col_heading level0 col6" >84-96</th>
#       <th id

# %% [markdown]
# ## Preparación de los datos para ingresarlos al modelo LASSO

# %%
#separamos los datos 
total_cum_list=ratios.values[0][0]#[0]
# total_cum_list=total_cum_list.reshape(-1)
np.shape(total_cum_list)
total_cum.origin
# Out:
# PeriodIndex(['1988', '1989', '1990', '1991', '1992', '1993', '1994', '1995',
#              '1996', '1997', '1998', '1999', '2000', '2001', '2002', '2003',
#              '2004', '2005', '2006'],
#             dtype='period[A-DEC]', name='origin')

# %%
#requerimos que los valores de X de entrada de la variable independiente tengan el mismo número de columnas
max_dev=max(total_cum.development)
X=np.array([[i.year,j] for i in total_cum.origin[:-1] for j in total_cum.development[1:]])#range(12,max_dev+12,12)])
print(np.shape(X))
# Out:
# (324, 2)

# %%
# (np.where(np.isnan(total_cum_list), total_cum_list, 0))
total_cum_list2=np.where(np.isnan(total_cum_list),0,total_cum_list)
total_cum_list2=total_cum_list2.reshape(-1)#[0]
# X[:19,:]
# X=X.reshape((19,19,2))
#X[:,1])
# for i in range(12,max_dev+12,12):
#     print(i)
print(np.shape(total_cum_list2))
# [x for x in total_cum_list2 if x!=0]
# total_cum.development.loc[2:]
np.shape(X)
# Out:
# (324,)
# (324, 2)

# %%
X_train, X_test, y_train, y_test=train_test_split(X,total_cum_list2)
np.shape(X_train)
np.shape(y_train)
# Out:
# (243,)

# %% [markdown]
# ## Implementación del modelo

# %%
clf=linear_model.Lasso(alpha=0.1)
clf.fit(X_train,y_train)
# np.shape(total_cum_list2)
print(clf.coef_)
print(clf.intercept_)
clf.predict(X_test)
# Out:
# [-0.04428967 -0.00496492]
# 89.37049509947867
# array([ 0.30978506,  0.31451988, -0.07511094,  0.74370556,  0.98202151,
#         0.65512622,  0.20749468,  0.7574166 , -0.20797996,  0.58025791,
#         0.87815285,  0.37409887,  0.10204774,  0.27023021,  0.38623164,
#        -0.39884969,  0.49167857,  0.41523199,  0.46425649,  1.15918019,
#         0.37567714,  0.42894303,  0.72683797,  0.0883367 ,  0.06091462,
#         0.28394125,  1.0247329 , -0.04453231,  0.69783761,  0.163205  ,
#        -0.02766472,  0.2122295 ,  0.16478328, -0.32555966,  0.67199381,
#         0.55125756,  0.53438997,  0.10678257,  1.20346986,  0.68412657,
#         0.4473889 ,  0.13262637, -0.23540204,  0.80486282,  0.72999452,
#        -0.42942832,  0.86286353, -0.20640168, -0.08882199, -0.19111237,
#         0.6398369 ,  0.12049361,  0.44896717,  0.89186389,  0.41996682,
#         0.53754652,  0.10362602,  0.45952166,  0.69941589, -0.10095475,
#        -0.14524442,  0.24122985, -0.029243  ,  0.02875771,  0.4046775 ,
#         0.14633741,  0.98044323, -0.414139  ,  0.28551953, -0.32398138,
#         0.25651917,  0.11733706, -0.13311166, -0.45842867,  0.00291391,
#         0.10520429,  1.01102186,  0.14949396,  0.36038783,  0.4901003 ,
#         0.50538961])

# %%
# print('age-to-age factors:')
# display(pd.DataFrame(X).heatmap(cmap='Reds'))
# Out:
# array([[1988,   24],
#        [1988,   36],
#        [1988,   48],
#        [1988,   60],
#        [1988,   72],
#        [1988,   84],
#        [1988,   96],
#        [1988,  108],
#        [1988,  120],
#        [1988,  132],
#        [1988,  144],
#        [1988,  156],
#        [1988,  168],
#        [1988,  180],
#        [1988,  192],
#        [1988,  204],
#        [1988,  216],
#        [1988,  228],
#        [1989,   24],
#        [1989,   36],
#        [1989,   48],
#        [1989,   60],
#        [1989,   72],
#        [1989,   84],
#        [1989,   96],
#        [1989,  108],
#        [1989,  120],
#        [1989,  132],
#        [1989,  144],
#        [1989,  156],
#        [1989,  168],
#        [1989,  180],
#        [1989,  192],
#        [1989,  204],
#        [1989,  216],
#        [1989,  228],
#        [1990,   24],
#        [1990,   36],
#        [1990,   48],
#        [1990,   60],
#        [1990,   72],
#        [1990,   84],
#        [1990,   96],
#        [1990,  108],
#        [1990,  120],
#        [1990,  132],
#        [1990,  144],
#        [1990,  156],
#        [1990,  168],
#        [1990,  180],
#        [1990,  192],
#        [1990,  204],
#        [1990,  216],
#        [1990,  228],
#        [1991,   24],
#        [1991,   36],
#        [1991,   48],
#        [1991,   60],
#        [1991,   72],
#        [1991,   84],
#        [1991,   96],
#        [1991,  108],
#        [1991,  120],
#        [1991,  132],
#        [1991,  144],
#        [1991,  156],
#        [1991,  168],
#        [1991,  180],
#        [1991,  192],
#        [1991,  204],
#        [1991,  216],
#        [1991,  228],
#        [1992,   24],
#        [1992,   36],
#        [1992,   48],
#        [1992,   60],
#        [1992,   72],
#        [1992,   84],
#        [1992,   96],
#        [1992,  108],
#        [1992,  120],
#        [1992,  132],
#        [1992,  144],
#        [1992,  156],
#        [1992,  168],
#        [1992,  180],
#        [1992,  192],
#        [1992,  204],
#        [1992,  216],
#        [1992,  228],
#        [1993,   24],
#        [1993,   36],
#        [1993,   48],
#        [1993,   60],
#        [1993,   72],
#        [1993,   84],
#        [1993,   96],
#        [1993,  108],
#        [1993,  120],
#        [1993,  132],
#        [1993,  144],
#        [1993,  156],
#        [1993,  168],
#        [1993,  180],
#        [1993,  192],
#        [1993,  204],
#        [1993,  216],
#        [1993,  228],
#        [1994,   24],
#        [1994,   36],
#        [1994,   48],
#        [1994,   60],
#        [1994,   72],
#        [1994,   84],
#        [1994,   96],
#        [1994,  108],
#        [1994,  120],
#        [1994,  132],
#        [1994,  144],
#        [1994,  156],
#        [1994,  168],
#        [1994,  180],
#        [1994,  192],
#        [1994,  204],
#        [1994,  216],
#        [1994,  228],
#        [1995,   24],
#        [1995,   36],
#        [1995,   48],
#        [1995,   60],
#        [1995,   72],
#        [1995,   84],
#        [1995,   96],
#        [1995,  108],
#        [1995,  120],
#        [1995,  132],
#        [1995,  144],
#        [1995,  156],
#        [1995,  168],
#        [1995,  180],
#        [1995,  192],
#        [1995,  204],
#        [1995,  216],
#        [1995,  228],
#        [1996,   24],
#        [1996,   36],
#        [1996,   48],
#        [1996,   60],
#        [1996,   72],
#        [1996,   84],
#        [1996,   96],
#        [1996,  108],
#        [1996,  120],
#        [1996,  132],
#        [1996,  144],
#        [1996,  156],
#        [1996,  168],
#        [1996,  180],
#        [1996,  192],
#        [1996,  204],
#        [1996,  216],
#        [1996,  228],
#        [1997,   24],
#        [1997,   36],
#        [1997,   48],
#        [1997,   60],
#        [1997,   72],
#        [1997,   84],
#        [1997,   96],
#        [1997,  108],
#        [1997,  120],
#        [1997,  132],
#        [1997,  144],
#        [1997,  156],
#        [1997,  168],
#        [1997,  180],
#        [1997,  192],
#        [1997,  204],
#        [1997,  216],
#        [1997,  228],
#        [1998,   24],
#        [1998,   36],
#        [1998,   48],
#        [1998,   60],
#        [1998,   72],
#        [1998,   84],
#        [1998,   96],
#        [1998,  108],
#        [1998,  120],
#        [1998,  132],
#        [1998,  144],
#        [1998,  156],
#        [1998,  168],
#        [1998,  180],
#        [1998,  192],
#        [1998,  204],
#        [1998,  216],
#        [1998,  228],
#        [1999,   24],
#        [1999,   36],
#        [1999,   48],
#        [1999,   60],
#        [1999,   72],
#        [1999,   84],
#        [1999,   96],
#        [1999,  108],
#        [1999,  120],
#        [1999,  132],
#        [1999,  144],
#        [1999,  156],
#        [1999,  168],
#        [1999,  180],
#        [1999,  192],
#        [1999,  204],
#        [1999,  216],
#        [1999,  228],
#        [2000,   24],
#        [2000,   36],
#        [2000,   48],
#        [2000,   60],
#        [2000,   72],
#        [2000,   84],
#        [2000,   96],
#        [2000,  108],
#        [2000,  120],
#        [2000,  132],
#        [2000,  144],
#        [2000,  156],
#        [2000,  168],
#        [2000,  180],
#        [2000,  192],
#        [2000,  204],
#        [2000,  216],
#        [2000,  228],
#        [2001,   24],
#        [2001,   36],
#        [2001,   48],
#        [2001,   60],
#        [2001,   72],
#        [2001,   84],
#        [2001,   96],
#        [2001,  108],
#        [2001,  120],
#        [2001,  132],
#        [2001,  144],
#        [2001,  156],
#        [2001,  168],
#        [2001,  180],
#        [2001,  192],
#        [2001,  204],
#        [2001,  216],
#        [2001,  228],
#        [2002,   24],
#        [2002,   36],
#        [2002,   48],
#        [2002,   60],
#        [2002,   72],
#        [2002,   84],
#        [2002,   96],
#        [2002,  108],
#        [2002,  120],
#        [2002,  132],
#        [2002,  144],
#        [2002,  156],
#        [2002,  168],
#        [2002,  180],
#        [2002,  192],
#        [2002,  204],
#        [2002,  216],
#        [2002,  228],
#        [2003,   24],
#        [2003,   36],
#        [2003,   48],
#        [2003,   60],
#        [2003,   72],
#        [2003,   84],
#        [2003,   96],
#        [2003,  108],
#        [2003,  120],
#        [2003,  132],
#        [2003,  144],
#        [2003,  156],
#        [2003,  168],
#        [2003,  180],
#        [2003,  192],
#        [2003,  204],
#        [2003,  216],
#        [2003,  228],
#        [2004,   24],
#        [2004,   36],
#        [2004,   48],
#        [2004,   60],
#        [2004,   72],
#        [2004,   84],
#        [2004,   96],
#        [2004,  108],
#        [2004,  120],
#        [2004,  132],
#        [2004,  144],
#        [2004,  156],
#        [2004,  168],
#        [2004,  180],
#        [2004,  192],
#        [2004,  204],
#        [2004,  216],
#        [2004,  228],
#        [2005,   24],
#        [2005,   36],
#        [2005,   48],
#        [2005,   60],
#        [2005,   72],
#        [2005,   84],
#        [2005,   96],
#        [2005,  108],
#        [2005,  120],
#        [2005,  132],
#        [2005,  144],
#        [2005,  156],
#        [2005,  168],
#        [2005,  180],
#        [2005,  192],
#        [2005,  204],
#        [2005,  216],
#        [2005,  228]])

# %%
prediction_table=pd.DataFrame(clf.predict(X).reshape(18,18),index=total_cum.origin[:-1],columns=total_cum.development[1:])
prediction_table.style.background_gradient(cmap='Reds')
# Out:
# <style type="text/css">
# #T_8ec97_row0_col0, #T_8ec97_row0_col1, #T_8ec97_row0_col2, #T_8ec97_row0_col3, #T_8ec97_row0_col4, #T_8ec97_row0_col5, #T_8ec97_row0_col6, #T_8ec97_row0_col7, #T_8ec97_row0_col8, #T_8ec97_row0_col9, #T_8ec97_row0_col10, #T_8ec97_row0_col11, #T_8ec97_row0_col12, #T_8ec97_row0_col13, #T_8ec97_row0_col14, #T_8ec97_row0_col15, #T_8ec97_row0_col16, #T_8ec97_row0_col17 {
#   background-color: #67000d;
#   color: #f1f1f1;
# }
# #T_8ec97_row1_col0, #T_8ec97_row1_col1, #T_8ec97_row1_col2, #T_8ec97_row1_col3, #T_8ec97_row1_col4, #T_8ec97_row1_col5, #T_8ec97_row1_col6, #T_8ec97_row1_col7, #T_8ec97_row1_col8, #T_8ec97_row1_col9, #T_8ec97_row1_col10, #T_8ec97_row1_col11, #T_8ec97_row1_col12, #T_8ec97_row1_col13, #T_8ec97_row1_col14, #T_8ec97_row1_col15, #T_8ec97_row1_col16, #T_8ec97_row1_col17 {
#   background-color: #840711;
#   color: #f1f1f1;
# }
# #T_8ec97_row2_col0, #T_8ec97_row2_col1, #T_8ec97_row2_col2, #T_8ec97_row2_col3, #T_8ec97_row2_col4, #T_8ec97_row2_col5, #T_8ec97_row2_col6, #T_8ec97_row2_col7, #T_8ec97_row2_col8, #T_8ec97_row2_col9, #T_8ec97_row2_col10, #T_8ec97_row2_col11, #T_8ec97_row2_col12, #T_8ec97_row2_col13, #T_8ec97_row2_col14, #T_8ec97_row2_col15, #T_8ec97_row2_col16, #T_8ec97_row2_col17 {
#   background-color: #a10e15;
#   color: #f1f1f1;
# }
# #T_8ec97_row3_col0, #T_8ec97_row3_col1, #T_8ec97_row3_col2, #T_8ec97_row3_col3, #T_8ec97_row3_col4, #T_8ec97_row3_col5, #T_8ec97_row3_col6, #T_8ec97_row3_col7, #T_8ec97_row3_col8, #T_8ec97_row3_col9, #T_8ec97_row3_col10, #T_8ec97_row3_col11, #T_8ec97_row3_col12, #T_8ec97_row3_col13, #T_8ec97_row3_col14, #T_8ec97_row3_col15, #T_8ec97_row3_col16, #T_8ec97_row3_col17 {
#   background-color: #b51318;
#   color: #f1f1f1;
# }
# #T_8ec97_row4_col0, #T_8ec97_row4_col1, #T_8ec97_row4_col2, #T_8ec97_row4_col3, #T_8ec97_row4_col4, #T_8ec97_row4_col5, #T_8ec97_row4_col6, #T_8ec97_row4_col7, #T_8ec97_row4_col8, #T_8ec97_row4_col9, #T_8ec97_row4_col10, #T_8ec97_row4_col11, #T_8ec97_row4_col12, #T_8ec97_row4_col13, #T_8ec97_row4_col14, #T_8ec97_row4_col15, #T_8ec97_row4_col16, #T_8ec97_row4_col17 {
#   background-color: #c7171c;
#   color: #f1f1f1;
# }
# #T_8ec97_row5_col0, #T_8ec97_row5_col1, #T_8ec97_row5_col2, #T_8ec97_row5_col3, #T_8ec97_row5_col4, #T_8ec97_row5_col5, #T_8ec97_row5_col6, #T_8ec97_row5_col7, #T_8ec97_row5_col8, #T_8ec97_row5_col9, #T_8ec97_row5_col10, #T_8ec97_row5_col11, #T_8ec97_row5_col12, #T_8ec97_row5_col13, #T_8ec97_row5_col14, #T_8ec97_row5_col15, #T_8ec97_row5_col16, #T_8ec97_row5_col17 {
#   background-color: #d82422;
#   color: #f1f1f1;
# }
# #T_8ec97_row6_col0, #T_8ec97_row6_col1, #T_8ec97_row6_col2, #T_8ec97_row6_col3, #T_8ec97_row6_col4, #T_8ec97_row6_col5, #T_8ec97_row6_col6, #T_8ec97_row6_col7, #T_8ec97_row6_col8, #T_8ec97_row6_col9, #T_8ec97_row6_col10, #T_8ec97_row6_col11, #T_8ec97_row6_col12, #T_8ec97_row6_col13, #T_8ec97_row6_col14, #T_8ec97_row6_col15, #T_8ec97_row6_col16, #T_8ec97_row6_col17 {
#   background-color: #e93529;
#   color: #f1f1f1;
# }
# #T_8ec97_row7_col0, #T_8ec97_row7_col1, #T_8ec97_row7_col2, #T_8ec97_row7_col3, #T_8ec97_row7_col4, #T_8ec97_row7_col5, #T_8ec97_row7_col6, #T_8ec97_row7_col7, #T_8ec97_row7_col8, #T_8ec97_row7_col9, #T_8ec97_row7_col10, #T_8ec97_row7_col11, #T_8ec97_row7_col12, #T_8ec97_row7_col13, #T_8ec97_row7_col14, #T_8ec97_row7_col15, #T_8ec97_row7_col16, #T_8ec97_row7_col17 {
#   background-color: #f34935;
#   color: #f1f1f1;
# }
# #T_8ec97_row8_col0, #T_8ec97_row8_col1, #T_8ec97_row8_col2, #T_8ec97_row8_col3, #T_8ec97_row8_col4, #T_8ec97_row8_col5, #T_8ec97_row8_col6, #T_8ec97_row8_col7, #T_8ec97_row8_col8, #T_8ec97_row8_col9, #T_8ec97_row8_col10, #T_8ec97_row8_col11, #T_8ec97_row8_col12, #T_8ec97_row8_col13, #T_8ec97_row8_col14, #T_8ec97_row8_col15, #T_8ec97_row8_col16, #T_8ec97_row8_col17 {
#   background-color: #f85f43;
#   color: #f1f1f1;
# }
# #T_8ec97_row9_col0, #T_8ec97_row9_col1, #T_8ec97_row9_col2, #T_8ec97_row9_col3, #T_8ec97_row9_col4, #T_8ec97_row9_col5, #T_8ec97_row9_col6, #T_8ec97_row9_col7, #T_8ec97_row9_col8, #T_8ec97_row9_col9, #T_8ec97_row9_col10, #T_8ec97_row9_col11, #T_8ec97_row9_col12, #T_8ec97_row9_col13, #T_8ec97_row9_col14, #T_8ec97_row9_col15, #T_8ec97_row9_col16, #T_8ec97_row9_col17 {
#   background-color: #fb7353;
#   color: #f1f1f1;
# }
# #T_8ec97_row10_col0, #T_8ec97_row10_col1, #T_8ec97_row10_col2, #T_8ec97_row10_col3, #T_8ec97_row10_col4, #T_8ec97_row10_col5, #T_8ec97_row10_col6, #T_8ec97_row10_col7, #T_8ec97_row10_col8, #T_8ec97_row10_col9, #T_8ec97_row10_col10, #T_8ec97_row10_col11, #T_8ec97_row10_col12, #T_8ec97_row10_col13, #T_8ec97_row10_col14, #T_8ec97_row10_col15, #T_8ec97_row10_col16, #T_8ec97_row10_col17 {
#   background-color: #fc8666;
#   color: #f1f1f1;
# }
# #T_8ec97_row11_col0, #T_8ec97_row11_col1, #T_8ec97_row11_col2, #T_8ec97_row11_col3, #T_8ec97_row11_col4, #T_8ec97_row11_col5, #T_8ec97_row11_col6, #T_8ec97_row11_col7, #T_8ec97_row11_col8, #T_8ec97_row11_col9, #T_8ec97_row11_col10, #T_8ec97_row11_col11, #T_8ec97_row11_col12, #T_8ec97_row11_col13, #T_8ec97_row11_col14, #T_8ec97_row11_col15, #T_8ec97_row11_col16, #T_8ec97_row11_col17 {
#   background-color: #fc997a;
#   color: #000000;
# }
# #T_8ec97_row12_col0, #T_8ec97_row12_col1, #T_8ec97_row12_col2, #T_8ec97_row12_col3, #T_8ec97_row12_col4, #T_8ec97_row12_col5, #T_8ec97_row12_col6, #T_8ec97_row12_col7, #T_8ec97_row12_col8, #T_8ec97_row12_col9, #T_8ec97_row12_col10, #T_8ec97_row12_col11, #T_8ec97_row12_col12, #T_8ec97_row12_col13, #T_8ec97_row12_col14, #T_8ec97_row12_col15, #T_8ec97_row12_col16, #T_8ec97_row12_col17 {
#   background-color: #fcad90;
#   color: #000000;
# }
# #T_8ec97_row13_col0, #T_8ec97_row13_col1, #T_8ec97_row13_col2, #T_8ec97_row13_col3, #T_8ec97_row13_col4, #T_8ec97_row13_col5, #T_8ec97_row13_col6, #T_8ec97_row13_col7, #T_8ec97_row13_col8, #T_8ec97_row13_col9, #T_8ec97_row13_col10, #T_8ec97_row13_col11, #T_8ec97_row13_col12, #T_8ec97_row13_col13, #T_8ec97_row13_col14, #T_8ec97_row13_col15, #T_8ec97_row13_col16, #T_8ec97_row13_col17 {
#   background-color: #fcbfa7;
#   color: #000000;
# }
# #T_8ec97_row14_col0, #T_8ec97_row14_col1, #T_8ec97_row14_col2, #T_8ec97_row14_col3, #T_8ec97_row14_col4, #T_8ec97_row14_col5, #T_8ec97_row14_col6, #T_8ec97_row14_col7, #T_8ec97_row14_col8, #T_8ec97_row14_col9, #T_8ec97_row14_col10, #T_8ec97_row14_col11, #T_8ec97_row14_col12, #T_8ec97_row14_col13, #T_8ec97_row14_col14, #T_8ec97_row14_col15, #T_8ec97_row14_col16, #T_8ec97_row14_col17 {
#   background-color: #fdd1be;
#   color: #000000;
# }
# #T_8ec97_row15_col0, #T_8ec97_row15_col1, #T_8ec97_row15_col2, #T_8ec97_row15_col3, #T_8ec97_row15_col4, #T_8ec97_row15_col5, #T_8ec97_row15_col6, #T_8ec97_row15_col7, #T_8ec97_row15_col8, #T_8ec97_row15_col9, #T_8ec97_row15_col10, #T_8ec97_row15_col11, #T_8ec97_row15_col12, #T_8ec97_row15_col13, #T_8ec97_row15_col14, #T_8ec97_row15_col15, #T_8ec97_row15_col16, #T_8ec97_row15_col17 {
#   background-color: #fee1d4;
#   color: #000000;
# }
# #T_8ec97_row16_col0, #T_8ec97_row16_col1, #T_8ec97_row16_col2, #T_8ec97_row16_col3, #T_8ec97_row16_col4, #T_8ec97_row16_col5, #T_8ec97_row16_col6, #T_8ec97_row16_col7, #T_8ec97_row16_col8, #T_8ec97_row16_col9, #T_8ec97_row16_col10, #T_8ec97_row16_col11, #T_8ec97_row16_col12, #T_8ec97_row16_col13, #T_8ec97_row16_col14, #T_8ec97_row16_col15, #T_8ec97_row16_col16, #T_8ec97_row16_col17 {
#   background-color: #ffebe2;
#   color: #000000;
# }
# #T_8ec97_row17_col0, #T_8ec97_row17_col1, #T_8ec97_row17_col2, #T_8ec97_row17_col3, #T_8ec97_row17_col4, #T_8ec97_row17_col5, #T_8ec97_row17_col6, #T_8ec97_row17_col7, #T_8ec97_row17_col8, #T_8ec97_row17_col9, #T_8ec97_row17_col10, #T_8ec97_row17_col11, #T_8ec97_row17_col12, #T_8ec97_row17_col13, #T_8ec97_row17_col14, #T_8ec97_row17_col15, #T_8ec97_row17_col16, #T_8ec97_row17_col17 {
#   background-color: #fff5f0;
#   color: #000000;
# }
# </style>
# <table id="T_8ec97">
#   <thead>
#     <tr>
#       <th class="index_name level0" >development</th>
#       <th id="T_8ec97_level0_col0" class="col_heading level0 col0" >24</th>
#       <th id="T_8ec97_level0_col1" class="col_heading level0 col1" >36</th>
#       <th id="T_8ec97_level0_col2" class="col_heading

# %%
y_pred=clf.predict(X_test)
mse = mean_squared_error(y_test, y_pred)
print(f'Mean Squared Error: {mse}')
# Out:
# Mean Squared Error: 0.16472598095591537

# %% [markdown]
# Se observa que los valores de los development factores $\lambda$ obtenidos mediante la técnica LASSO aumentan en una dirección en particular (hacia el origen y development iniciales). Esto se debe a que al hacer el modelamiento con LASSO la salida es la de un plano tridimensional de la forma:
#
# $$ax+by+cz=d$$
#
# Siendo $(a,b,c)$ el vector normal, la proyección (a,b) nos indica la dirección de mayor crecimiento de z en el mapa de calor realizado, qque como deciamos antes es hacia la esquina superior izquierda.
